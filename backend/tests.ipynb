# %%
from chatbot_multi_agent import chatbot

# %%
from IPython.display import Image, display
from langchain_core.runnables.graph import CurveStyle, MermaidDrawMethod, NodeStyles

display(
    Image(
        chatbot.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
        )
    )
)

# %%
chatbot.invoke({
    'chat_history':[('human','hola!')],
    })
# Out:
# {'chat_history': [('human', 'hola!'),
#   AIMessage(content='¡Hola! ¿En qué puedo ayudarte hoy?', name='generalist')],
#  'designated_agent': 'out_of_scope'}

# %%
keep_going = True
chat_history = []
while keep_going:
    user_input = input('You: ')
    if user_input == 'exit':
        keep_going = False
    else:
        print(user_input)
        chat_history.append(('human',user_input))
        response = chatbot.invoke({'chat_history':chat_history})
        print(response['chat_history'][-1].content)
        chat_history.append(('ai',response['chat_history'][-1].content))
# Out:
# hola
# ¡Hola! ¿En qué puedo ayudarte hoy?
# necesito saber qué farmacias estan de turno hoy
# I am a pharmacy store specialist
# me puedes recomendar algo para el dolor de cabeza?
# I am a pharmacy store specialist and I can help you with information about pharmacy stores and pharmaceutical drugs in Chile. If you are looking for medication recommendations, I recommend consulting a doctor. Let me know if you need help finding a pharmacy store or any other information related to that.
# vuelve a responder en español
# ¡Claro! Soy un asistente especializado en información sobre farmacias y medicamentos en Chile. Si estás buscando recomendaciones de medicamentos, te recomiendo que consultes a un médico. Avísame si necesitas ayuda para encontrar una farmacia de turno u otra información relacionada. ¡Estoy aquí para ayudarte!
# puedes recomendarme algo para la espalda?
# ...
